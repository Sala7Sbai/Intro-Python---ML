# %% [markdown]
# ## TP2: MatplotLib - Pandas
# ### SBAI SALAH
#
# ```
# https://jkarakas.github.io/Exploratory-Analysis-of-the-Titanic-Dataset/Titanic_Dataset_Exploratory_Analysis._With_Code.html
#
# ```

# %% [markdown]
# ## A - La bibliothèque matplotlib

# %% [markdown]
# ### Q1 : Sin function

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
x = np.linspace(0,15,200)
T= np.sin(x)  
plt.figure()
plt.plot(x,T,'r')
plt.xlabel('x')
plt.ylabel('y = sin(x)')
plt.title('La fonction sinus')
plt.show()

# %% [markdown]
# ### Q2

# %%
import random as rd
x1= []
x2= []
x3 =[]
y1= []
y2= []
y3 =[]

#pour les nuages rouge
for i in range(50) :
    x1.append(rd.uniform(10,15))
for i in range(50) :
    y1.append(rd.uniform(10,15))

#pour les nuages bleu
for i in range(100) :
    x2.append(rd.uniform(0,17.5))
for i in range(100) :
    y2.append(rd.uniform(5,17.5))
    

#pour les nuages vert
for i in range(50) :
    x3.append(rd.uniform(0,5))
for i in range(50) :
    y3.append(rd.uniform(0,5))

    
plt.figure()
plt.scatter(x1,y1,c="r")
plt.scatter(x2,y2,c="b")
plt.scatter(x3,y3,c="g")
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %% [markdown]
# ### BONUS : TSP

# %%
#trace les données d'un problème de voyageur de commerce
import matplotlib.pyplot as plt
x = [0,1,2,3,4,5,0] 
y = [3,6,6,3,2,1,3]
plt.figure()
plt.scatter(x,y,c = "g")
plt.plot(x,y,c = "r")
plt.title("graphe du problème de voyageur de commerce")
plt.show()

# %% [markdown]
# ## B - La bibliothèque Pandas

# %% [markdown]
# ```
# Voici quelques fonctions est méthodes fournit par pandas pour la manipulation des
# DataFrames :
#
# >> Pour créer un dataframe à partir des fichiers de donnees :
#
# - pandas.read_excel() ou pd.read_excel() : pour les fichiers (.xls)
# - pd.read_csv() : pour les fichiers (.csv).
# - pd.read_json() : pour les fichiers (.json).
# - ...
# - C’est possible aussi de créer un DataFrame à partir d’un tableau :
#   df = pd.Series([1, 2, 3, 4, …])
#
# >> La selection:
# - df['column_name']
# - df[num_row_start:num_row_end]
# - df.loc[num_row, ['column_name', 'column_name'], ...]
#
# >> La modification:
# - df.at[num_row, "column_name"] = value
#
# >> Filtrer les datas:
#
#
#
#
#
#
# ```

# %% [markdown]
# ### Q1 : Read excel file

# %%
import pandas as pd

df = pd.read_excel('titanic.xls')
df[0:]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# ### Q2: five first lines

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ### Q3: five last lines

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %% [markdown]
# ### Q4: lines from 6 to 10

# %%
df[6:11]
# Out:
#     pclass  survived                                           name     sex  \
# 6        1         1              Andrews, Miss. Kornelia Theodosia  female
# 7        1         0                         Andrews, Mr. Thomas Jr    male
# 8        1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9        1         0                        Artagaveytia, Mr. Ramon    male
# 10       1         0                         Astor, Col. John Jacob    male
#
#      age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 6   63.0      1      0     13502   77.9583       D7        S   10    NaN
# 7   39.0      0      0    112050    0.0000      A36        S  NaN    NaN
# 8   53.0      2      0     11769   51.4792     C101        S    D    NaN
# 9   71.0      0      0  PC 17609   49.5042      NaN        C  NaN   22.0
# 10  47.0      1      0  PC 17757  227.5250  C62 C64        C  NaN  124.0
#
#               home.dest
# 6            Hudson, NY
# ...

# %% [markdown]
# ### Q5: Value of column name of the 5th line

# %%
df.loc[5, "name"]
# Out:
# 'Anderson, Mr. Harry'

# %% [markdown]
# ### Q6: data of passengers with age > 30 yo

# %%
df[df["age"] > 30]
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                 Widegren, Mr. Carl/Charles Peter
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1298       3         0                        Wittevrongel, Mr. Camille
# 1301       3         0                             Youseff, Mr. Gerious
#
#          sex   age  sibsp  parch    ticket     fare cabin embarked boat  \
# ...

# %% [markdown]
# ### Q7: data of female passengers with age < 25 yo

# %%
df[(df["sex"] == "female") & (df["age"]< 25)]
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 36         1         1                        Bowerman, Miss. Elsie Edith
# ...      ...       ...                                                ...
# 1265       3         0                          Van Impe, Miss. Catharina
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                               Zabour, Miss. Hileni
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ### Q8: count male passengers

# %%
len(df[df["sex"] == "male"])
# Out:
# 843

# %% [markdown]
# ### Q9: count passengers who survived

# %%
a = len(df[df["survived"] == 1])
print(f"{a} Survived ")
# Out:
# 500 Survived

# %% [markdown]
# ### Q10: Matplotlib & pandas
# ```
# Écrivez un script Matplotlib qui affiche le nombre de passagers par sexe dans un
# graphe de type bar.
#
# ```

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
Psex = ['male', 'female']
Pcount = [df['male'].count_values(), 

students = [23,17]
ax.bar(langs,students)
plt.show()

# %%
#make a copy of the dataframe 
dfc = df.copy()

dfc.loc[:,'embarked'].replace(['C','S','Q'],
['Cherbourg','Southampton','Queenstown'], inplace=True)


dfc.loc[:,'survived'].replace([0,1],['No','Yes'],inplace=True)

dfc[0:]
# Out:
#       pclass survived                                             name  \
# 0          1      Yes                    Allen, Miss. Elisabeth Walton
# 1          1      Yes                   Allison, Master. Hudson Trevor
# 2          1       No                     Allison, Miss. Helen Loraine
# 3          1       No             Allison, Mr. Hudson Joshua Creighton
# 4          1       No  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...      ...                                              ...
# 1304       3       No                             Zabour, Miss. Hileni
# 1305       3       No                            Zabour, Miss. Thamine
# 1306       3       No                        Zakarian, Mr. Mapriededer
# 1307       3       No                              Zakarian, Mr. Ortin
# 1308       3       No                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin     embarked  \
# ...

# %%
import seaborn as sb

def plotiKolchi(df, col, plt_style = 'seaborn-ticks', color_palette = "bright"):

    dataGroupe=pd.DataFrame()
    dataGroupe['{} No'.format(col)] = df.groupby(col).size()
    dataGroupe['{} Proportion'.format(col)] = np.round(dataGroupe['{} No'.format(col)].divide(dataGroupe['{} No'.format(col)].sum())*100,0)
    
    print ('Nombre total :  {}:{}'.format(col,dataGroupe['{} No'.format(col)].sum()))
    
    plt.style.use(plt_style)
    sb.set_palette(sb.color_palette(color_palette))
    
    fig=plt.figure()
    
    aaa=dataGroupe['{} No'.format(col)].plot(kind='bar', title='{} Column'.format(col), figsize=(16,8), color=sb.color_palette())
    
    for p in aaa.patches: 
        aaa.annotate(np.round(p.get_height(),decimals=2),
                    (p.get_x()+p.get_width()/2., p.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# %%
plotiKolchi(dfc, 'sex')
plotiKolchi(dfc, 'survived')
plotiKolchi(dfc, 'age')
# Out:
# Nombre total :  sex:1309
# Nombre total :  survived:1309
# Nombre total :  age:1046
